# %% [markdown]
# <a href="https://colab.research.google.com/github/aitashii/ai-ml-studies/blob/main/Cwiczenia-programowanie/podstawy-programowania.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Podstawy programowania (Python) - ZESTAW PODSTAWOWY
#
# Autor: Ola
# Data: 2026-02-07
# Przedmiot: Wprowadzenie do programowania

# %% [markdown]
# ---
# ## 1. Wprowadzenie i pierwszy program

# %% [markdown]
# ### Zadanie 1.1
# **Polecenie:** Uruchom środowisko programistyczne (IDLE / VS Code / PyCharm). Napisz program, który wypisze na ekranie:
# ```
# Kod
# Witaj w świecie programowania!
# ```

# %%
# Zadanie 1.1 - Pierwszy program w Pythonie
print("Kod")
print("Witaj w świecie programowania!")

# %% [markdown]
# ### Zadanie 1.2
# **Polecenie:** Napisz program, który wypisze Twoją imię, kierunek studiów i rok rozpoczęcia studiów.
# **Format:** Użyj `2. Typy danych, zmienne, operatory, wejście/wyjście`

# %%
# Zadanie 1.2 - Informacje o studencie
imie = "Ola"
kierunek = "Informatyka"
rok_rozpoczecia = 2025

print("Imię:", imie)
print("Kierunek studiów:", kierunek)
print("Rok rozpoczęcia studiów:", rok_rozpoczecia)

# %% [markdown]
# ---
# ## 2. Typy danych, zmienne, operatory, wejście/wyjście

# %% [markdown]
# ### Zadanie 2.1
# **Polecenie:** Pobierz od użytkownika dwie liczby i wypisz:
# - ich sumę
# - różnicę
# - iloczyn
# - wynik dzielenia

# %%
# Zadanie 2.1 - Kalkulator podstawowy
liczba1 = float(input("Podaj pierwszą liczbę: "))
liczba2 = float(input("Podaj drugą liczbę: "))

suma = liczba1 + liczba2
roznica = liczba1 - liczba2
iloczyn = liczba1 * liczba2

# Sprawdzamy dzielenie przez zero
if liczba2 != 0:
    dzielenie = liczba1 / liczba2
    print(f"\nWyniki operacji:")
    print(f"Suma: {liczba1} + {liczba2} = {suma}")
    print(f"Różnica: {liczba1} - {liczba2} = {roznica}")
    print(f"Iloczyn: {liczba1} * {liczba2} = {iloczyn}")
    print(f"Dzielenie: {liczba1} / {liczba2} = {dzielenie}")
else:
    print(f"\nWyniki operacji:")
    print(f"Suma: {liczba1} + {liczba2} = {suma}")
    print(f"Różnica: {liczba1} - {liczba2} = {roznica}")
    print(f"Iloczyn: {liczba1} * {liczba2} = {iloczyn}")
    print(f"Dzielenie: Nie można dzielić przez zero!")

# %% [markdown]
# ### Zadanie 2.2
# **Polecenie:** Pobierz od użytkownika imię i wypisz komunikat: `"Witaj, <imię>!"`

# %%
# Zadanie 2.2 - Powitanie użytkownika
imie_uzytkownika = input("Podaj swoje imię: ")
print(f"Witaj, {imie_uzytkownika}!")

# %% [markdown]
# ### Zadanie 2.3
# **Polecenie:** Sprawdź typy danych poniższych wartości, używając `type()`:
# ```
# Kod
# 42
# 3.14
# "Python"
# True
# ```

# %%
# Zadanie 2.3 - Sprawdzenie typów danych
wartosci = [
    ("Kod", "Kod"),
    ("42", 42),
    ("3.14", 3.14),
    ('"Python"', "Python"),
    ("True", True)
]

print("Sprawdzenie typów danych:\n")
for nazwa, wartosc in wartosci:
    print(f"{nazwa:15} -> Typ: {type(wartosc).__name__:10} -> Wartość: {wartosc}")

# %% [markdown]
# ---
# ## 3. Instrukcje warunkowe

# %% [markdown]
# ### Zadanie 3.1
# **Polecenie:** Napisz program, który sprawdza, czy podana liczba jest:
# - dodatnia
# - ujemna
# - równa zero

# %%
# Zadanie 3.1 - Sprawdzenie znaku liczby
liczba = float(input("Podaj liczbę: "))

if liczba > 0:
    print(f"Liczba {liczba} jest dodatnia.")
elif liczba < 0:
    print(f"Liczba {liczba} jest ujemna.")
else:
    print(f"Liczba jest równa zero.")

# %% [markdown]
# ### Zadanie 3.2
# **Polecenie:** Napisz program sprawdzający, czy liczba jest parzysta.

# %%
# Zadanie 3.2 - Sprawdzenie parzystości
liczba = int(input("Podaj liczbę całkowitą: "))

if liczba % 2 == 0:
    print(f"Liczba {liczba} jest parzysta.")
else:
    print(f"Liczba {liczba} jest nieparzysta.")

# %% [markdown]
# ### Zadanie 3.3
# **Polecenie:** Napisz program, który pobiera wynik testu (0-100) i wypisuje ocenę według skali:
# - 90-100: 5
# - 75-89: 4
# - 60-74: 3
# - 0-59: 2

# %%
# Zadanie 3.3 - System oceniania
wynik = float(input("Podaj wynik testu (0-100): "))

# Walidacja zakresu
if wynik < 0 or wynik > 100:
    print("Błąd! Wynik musi być w zakresie 0-100.")
else:
    if wynik >= 90:
        ocena = 5
    elif wynik >= 75:
        ocena = 4
    elif wynik >= 60:
        ocena = 3
    else:
        ocena = 2
    
    print(f"Wynik testu: {wynik} punktów -> Ocena: {ocena}")

# %% [markdown]
# ---
# ## 4. Pętle (for, while)

# %% [markdown]
# ### Zadanie 4.1
# **Polecenie:** Wyświetl liczby od 1 do 20.

# %%
# Zadanie 4.1 - Wyświetlanie liczb od 1 do 20
print("Liczby od 1 do 20:")
for i in range(1, 21):
    print(i, end=" ")
print()  # Nowa linia na końcu

# %% [markdown]
# ### Zadanie 4.2
# **Polecenie:** Policz sumę liczb od 1 do n (n podaje użytkownik).

# %%
# Zadanie 4.2 - Suma liczb od 1 do n
n = int(input("Podaj liczbę n: "))

suma = 0
for i in range(1, n + 1):
    suma += i

print(f"Suma liczb od 1 do {n} wynosi: {suma}")

# Sprawdzenie za pomocą wzoru matematycznego: suma = n * (n + 1) / 2
suma_matematyczna = n * (n + 1) // 2
print(f"Sprawdzenie (wzór matematyczny): {suma_matematyczna}")

# %% [markdown]
# ### Zadanie 4.3
# **Polecenie:** Narysuj prostokąt z gwiazdek o wymiarach podanych przez użytkownika, np.:
# ```
# Kod
# ****
# ****
# ****
# ```

# %%
# Zadanie 4.3 - Prostokąt z gwiazdek
szerokosc = int(input("Podaj szerokość prostokąta: "))
wysokosc = int(input("Podaj wysokość prostokąta: "))

print("\nKod")
for i in range(wysokosc):
    print("*" * szerokosc)

# %% [markdown]
# ### Zadanie 4.4
# **Polecenie:** Narysuj prostą "choinkę" ("Zapytaj liczbę" od 1 do 20).

# %%
# Zadanie 4.4 - Choinka z gwiazdek
wysokosc = int(input("Podaj wysokość choinki (1-20): "))

# Walidacja zakresu
if wysokosc < 1 or wysokosc > 20:
    print("Błąd! Wysokość musi być w zakresie 1-20.")
else:
    print("\nChoinka:")
    for i in range(1, wysokosc + 1):
        # Wyświetl spacje do wyśrodkowania
        spacje = " " * (wysokosc - i)
        # Wyświetl gwiazdki
        gwiazdki = "*" * (2 * i - 1)
        print(spacje + gwiazdki)
    
    # Opcjonalnie: pień choinki
    pien_spacje = " " * (wysokosc - 1)
    print(pien_spacje + "*")

# %% [markdown]
# ---
# ## Podsumowanie
#
# W tym notebooku rozwiązaliśmy podstawowe zadania z programowania w Pythonie, obejmujące:
#
# 1. **Wprowadzenie i pierwszy program** - podstawowe komendy `print()` i zmienne
# 2. **Typy danych i operatory** - operacje matematyczne, input/output, sprawdzanie typów
# 3. **Instrukcje warunkowe** - `if`, `elif`, `else` do kontroli przepływu programu
# 4. **Pętle** - `for` i `while` do iteracji i tworzenia wzorów
#
# Każde zadanie zawiera:
# - Dokładny opis polecenia
# - Komentarze w kodzie wyjaśniające logikę
# - Walidację danych wejściowych gdzie to konieczne
# - Czytelne formatowanie wyników
#
# ---
# **Utworzono za pomocą Claude Code**
# Repository: [ai-ml-studies](https://github.com/aitashii/ai-ml-studies)

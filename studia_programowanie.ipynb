# %% [markdown]
# <a href="https://colab.research.google.com/github/aitashii/ai-ml-studies/blob/main/studia_programowanie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programowanie AL & ML

# %%
def calculate_product_or_sum(liczba1, liczba2):
    product = liczba1 * liczba2
    if product <= 1000:
        return product
    else:
        return liczba1 + liczba2

# Test Case 1
liczba1_1 = 20
liczba2_1 = 30
result_1 = calculate_product_or_sum(liczba1_1, liczba2_1)
print(f"Biorąc pod uwagę 1:\nliczba1 = {liczba1_1}\nliczba2 = {liczba2_1}\noczekiwany wynik:\nwynik to {result_1}")

print("\n" + "-"*20 + "\n")

# Test Case 2
liczba1_2 = 40
liczba2_2 = 30
result_2 = calculate_product_or_sum(liczba1_2, liczba2_2)
print(f"Biorąc pod uwagę 2:\nliczba1 = {liczba1_2}\nliczba2 = {liczba2_2}\noczekiwany wynik:\nwynik to {result_2}")
# Out:
# Biorąc pod uwagę 1:
# liczba1 = 20
# liczba2 = 30
# oczekiwany wynik:
# wynik to 600
#
# --------------------
#
# Biorąc pod uwagę 2:
# liczba1 = 40
# liczba2 = 30
# oczekiwany wynik:
# wynik to 70

# %%
previous_num = 0

print("Iteracja | Bieżąca Liczba | Poprzednia Liczba | Suma")
print("-------- | -------------- | ---------------- | ----")

for i in range(10): # Iteruje przez liczby od 0 do 9 (pierwsze 10 liczb)
    current_num = i
    current_sum = current_num + previous_num
    print(f"{i+1:<8} | {current_num:<14} | {previous_num:<16} | {current_sum}")
    previous_num = current_num
# Out:
# Iteracja | Bieżąca Liczba | Poprzednia Liczba | Suma
# -------- | -------------- | ---------------- | ----
# 1        | 0              | 0                | 0
# 2        | 1              | 0                | 1
# 3        | 2              | 1                | 3
# 4        | 3              | 2                | 5
# 5        | 4              | 3                | 7
# 6        | 5              | 4                | 9
# 7        | 6              | 5                | 11
# 8        | 7              | 6                | 13
# 9        | 8              | 7                | 15
# 10       | 9              | 8                | 17

# %%
for i in range(1, 6):
    print(str(i) * i)
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
num_rows = 5 # Możesz zmienić tę wartość, aby uzyskać inną wysokość piramidy

for i in range(num_rows, 0, -1):
    print("*" * i)
# Out:
# *****
# ****
# ***
# **
# *

# %% [markdown]
# # notebook + github

# %%
print('Sprawdzam status repozytorium:')
# !git status
# Out:
# Sprawdzam status repozytorium:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
print('Dodaję wszystkie zmienione pliki do obszaru przejściowego:')
# !git add .
# Out:
# Dodaję wszystkie zmienione pliki do obszaru przejściowego:

# %%
commit_message = "Aktualizacja notebooka Colab z przykładami AL/ML"
print(f'Zatwierdzam zmiany z wiadomością: "{commit_message}"')
# !git commit -m "{commit_message}"
# Out:
# Zatwierdzam zmiany z wiadomością: "Aktualizacja notebooka Colab z przykładami AL/ML"
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@00d59aab7ac4.(none)')

# %%
print('Pcham zmiany do zdalnego repozytorium (main branch):')
# !git push origin main
# Out:
# Pcham zmiany do zdalnego repozytorium (main branch):
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# In a Colab cell:
# !git clone https://github.com/aitashii/ai-ml-studies.git
# %cd ai-ml-studies
# Out:
# Cloning into 'ai-ml-studies'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 1), reused 7 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.
# Resolving deltas: 100% (1/1), done.
# /content/ai-ml-studies/ai-ml-studies
